# %%
# !pip install unstructured > /dev/null

# %%
# !pip install -Uq markdown langchain openai tiktoken supabase python-dotenv

# %%
from langchain.document_loaders import UnstructuredMarkdownLoader
import glob
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.text_splitter import MarkdownHeaderTextSplitter

# Path to the 'docs/' directory, assuming 'docs/' is in the current working directory
docs_path = './docs/**/*.mdx'

# Use glob.glob to match all .mdx files in the directory and subdirectories
mdx_files = glob.glob(docs_path, recursive=True)

docs = []

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

for file_path in mdx_files:
    print(file_path)
    # loader = UnstructuredMarkdownLoader(file_path=mdx_file)
    # doc = loader.load_and_split(text_splitter=text_splitter)
    # docs = [*docs, *doc]

    with open(file_path, 'r', encoding='utf-8') as file:
        mdx_content = file.read()
        headers_to_split_on = [
            ("#", "Header 1"),
            ("##", "Header 2"),
            ("###", "Header 3"),
        ]

        markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
        md_header_splits = markdown_splitter.split_text(mdx_content)

        # Split
        splits = text_splitter.split_documents(md_header_splits)
        docs = [*docs, *splits]

len(docs)
# Out:
# ./docs/stroke-width.mdx
# ./docs/columns.mdx
# ./docs/transition-duration.mdx
# ./docs/grid-column.mdx
# ./docs/backdrop-brightness.mdx
# ./docs/scroll-snap-type.mdx
# ./docs/configuration.mdx
# ./docs/pointer-events.mdx
# ./docs/padding.mdx
# ./docs/box-sizing.mdx
# ./docs/translate.mdx
# ./docs/divide-style.mdx
# ./docs/drop-shadow.mdx
# ./docs/content.mdx
# ./docs/outline-width.mdx
# ./docs/transition-delay.mdx
# ./docs/plugins.mdx
# ./docs/ring-offset-color.mdx
# ./docs/user-select.mdx
# ./docs/flex-basis.mdx
# ./docs/hue-rotate.mdx
# ./docs/theme.mdx
# ./docs/caret-color.mdx
# ./docs/grid-row.mdx
# ./docs/transform-origin.mdx
# ./docs/background-image.mdx
# ./docs/justify-content.mdx
# ./docs/transition-timing-function.mdx
# ./docs/animation.mdx
# ./docs/grayscale.mdx
# ./docs/grid-auto-rows.mdx
# ./docs/box-decoration-break.mdx
# ./docs/visibility.mdx
# ./docs/max-width.mdx
# ./docs/rotate.mdx
# ./docs/grid-template-columns.mdx
# ./docs/blur.mdx
# ./docs/max-height.mdx
# ./docs/upgrade-guide.mdx
# ./docs/scroll-snap-stop.mdx
# ./docs/ring-width.mdx
# ./docs/touch-action.mdx
# ./docs/table-layout.mdx
# ./docs/border-collapse.mdx
# ./docs/box-shadow.mdx
# ./docs/box-shadow-color.mdx
# ./docs/clear.mdx
# ./docs/font-smoothing.mdx
# ./docs/backdrop-grayscale.mdx
# ./docs/screen-readers.mdx
# ./docs/flex.mdx
# ./docs/float.mdx
# ./docs/flex-shrink.mdx
# ./docs/skew.mdx
# ./docs/contrast.mdx
# ./docs/backdrop-contrast.mdx
# ./docs/text-align.mdx
# ./docs/font-size.mdx
# ./docs/flex-wrap.mdx
# ./docs/font-weight.mdx
# ./docs/functions-and-directives.mdx
# ./docs/align-self.mdx
# ./docs/screens.mdx
# ./docs/list-style-type.mdx
# ./docs/isolation.mdx
# ./docs/background-position.mdx
# ./docs/order.mdx
# ./docs/aspect-ratio.mdx
# ./docs/position.mdx
# ./docs/break-after.mdx
# ./docs/border-width.mdx
# ./docs/play-cdn.mdx
# ./docs/space.mdx
# ./docs/stroke.mdx
# ./docs/width.mdx
# ./docs/flex-direction.mdx
# ./docs/divide-color.mdx
# ./docs/justify-items.mdx
# ./docs/sepia.mdx
# ./docs/object-position.mdx
# ./docs/transition-property.mdx
# ./docs/overflow.mdx
# ./docs/container.mdx
# ./docs/align-items.mdx
# ./docs/using-with-preprocessors.mdx
# ./docs/place-self.mdx
# ./docs/cursor.mdx
# ./docs/backdrop-sepia.mdx
# ./docs/background-color.mdx
# ./docs/grid-auto-flow.mdx
# ./docs/backdrop-blur.mdx
# ./docs/adding-new-utilities.mdx
# ./docs/utility-first.mdx
# ./docs/place-items.mdx
# ./docs/list-style-image.mdx
# ./docs/outline-offset.mdx
# ./docs/customizing-spacing.mdx
# ./docs/adding-custom-styles.mdx
# ./docs/scale.mdx
# ./docs/grid-auto-columns.mdx
# ./docs/backdrop-opacity.mdx
# ./docs/line-height.mdx
# ./docs/text-overflow.mdx
# ./docs/mix-blend-mode.mdx
# ./docs/saturate.mdx
# ./docs/adding-base-styles.mdx
# ./docs/background-clip.mdx
# ./docs/invert.mdx
# ./docs/hyphens.mdx
# ./docs/opacity.mdx
# ./docs/vertical-align.mdx
# ./docs/font-variant-numeric.mdx
# ./docs/preflight.mdx
# ./docs/customizing-colors.mdx
# ./docs/outline-color.mdx
# ./docs/text-transform.mdx
# ./docs/appearance.mdx
# ./docs/text-decoration-color.mdx
# ./docs/border-spacing.mdx
# ./docs/border-style.mdx
# ./docs/break-before.mdx
# ./docs/font-family.mdx
# ./docs/text-indent.mdx
# ./docs/ring-offset-width.mdx
# ./docs/list-style-position.mdx
# ./docs/responsive-design.mdx
# ./docs/text-decoration-thickness.mdx
# ./docs/z-index.mdx
# ./docs/will-change.mdx
# ./docs/min-height.mdx
# ./docs/editor-setup.mdx
# ./docs/scroll-behavior.mdx
# ./docs/scroll-snap-align.mdx
# ./docs/grid-template-rows.mdx
# ./docs/ring-color.mdx
# ./docs/resize.mdx
# ./docs/text-color.mdx
# ./docs/break-inside.mdx
# ./docs/justify-self.mdx
# ./docs/whitespace.mdx
# ./docs/margin.mdx
# ./docs/background-size.mdx
# ./docs/letter-spacing.mdx
# ./docs/align-content.mdx
# ./docs/text-underline-offset.mdx
# ./docs/height.mdx
# ./docs/scroll-margin.mdx
# ./docs/scroll-padding.mdx
# ./docs/background-blend-mode.mdx
# ./docs/accent-color.mdx
# ./docs/backdrop-invert.mdx
# ./docs/presets.mdx
# ./docs/min-width.mdx
# ./docs/border-radius.mdx
# ./docs/flex-grow.mdx
# ./docs/reusing-styles.mdx
# ./docs/border-color.mdx
# ./docs/line-clamp.mdx
# ./docs/font-style.mdx
# ./docs/text-decoration-style.mdx
# ./docs/divide-width.mdx
# ./docs/outline-style.mdx
# ./docs/object-fit.mdx
# ./docs/display.mdx
# ./docs/place-content.mdx
# ./docs/content-configuration.mdx
# ./docs/background-attachment.mdx
# ./docs/hover-focus-and-other-states.mdx
# ./docs/brightness.mdx
# ./docs/text-decoration.mdx
# ./docs/background-repeat.mdx
# ./docs/gap.mdx
# ./docs/top-right-bottom-left.mdx
# ./docs/fill.mdx
# ./docs/gradient-color-stops.mdx
# ./docs/typography-plugin.mdx
# ./docs/caption-side.mdx
# ./docs/overscroll-behavior.mdx
# ./docs/word-break.mdx
# ./docs/optimizing-for-production.mdx
# ./docs/dark-mode.mdx
# ./docs/tailwind-cli.mdx
# ./docs/backdrop-saturate.mdx
# ./docs/background-origin.mdx
# ./docs/browser-support.mdx
# ./docs/backdrop-hue-rotate.mdx
# 1960

# %%
from supabase.client import Client, create_client
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores.supabase import SupabaseVectorStore
import os
from dotenv import load_dotenv

load_dotenv()

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

embeddings = OpenAIEmbeddings()

docs[10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yjkim/Developer/whatsupdocc/tailwind_docs_rag.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/Users/yjkim/Developer/whatsupdocc/tailwind_docs_rag.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> supabase: Client = create_client(supabase_url, supabase_key)
#      <a href='vscode-notebook-cell:/Users/yjkim/Developer/whatsupdocc/tailwind_docs_rag.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> embeddings = OpenAIEmbeddings()
# ---> <a href='vscode-notebook-cell:/Users/yjkim/Developer/whatsupdocc/tailwind_docs_rag.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> docs[10]
#
# NameError: name 'docs' is not defined

# %%
# vector_store = SupabaseVectorStore.from_documents(
#     documents=docs[600:],
#     embedding=embeddings,
#     client=supabase,
#     table_name="tailwind_documents",
#     query_name="match_tailwind_documents",
#     # table_name="documents",
#     # query_name="match_documents",
#     chunk_size=100,
#     # show_progress=True
# )

vector_store = SupabaseVectorStore(
    embedding=embeddings,
    client=supabase,
    chunk_size=100,
    table_name="tailwind_documents",
    query_name="match_tailwind_documents",
)

# from typing import List

# chunk_size = 500  # You can modify this value to a smaller number
# id_list: List[str] = []
# for i in range(0, len(docs), chunk_size):
#     chunk = docs[i : i + chunk_size]

#     result = supabase.from_("tailwind_documents").upsert(chunk).execute()  # type: ignore

#     if len(result.data) == 0:
#         raise Exception("Error inserting: No rows added")

#     # VectorStore.add_vectors returns ids as strings
#     ids = [str(i.get("id")) for i in result.data if i.get("id")]

#     id_list.extend(ids)

# %% [markdown]
# ## DocumentCompressorPipeline
#
# Since a lot of context could be retreived per query we want to chain a few compression and reordering steps as necessary to optimize what gets fed to the final context.

# %%
# Helper function for printing docs

def pretty_print_docs(docs):
    print(f"\n{'-' * 100}\n".join([f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]))

# %%
docs = vector_store.as_retriever().get_relevant_documents("What is the correct way to apply a gradient to a div?")
pretty_print_docs(docs)
# Out:
# 2023-11-06 20:14:44,306:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/rpc/match_tailwind_documents?limit=4 "HTTP/1.1 200 OK"
# Document 1:
#
# <div class="relative">
# <div class="absolute inset-6 backdrop-brightness-200 h-20 w-20 bg-white/30"></div>
# <img class="w-32 h-32 object-cover rounded-lg shadow-xl" src="https://images.unsplash.com/photo-1554629947-334ff61d85dc?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=320&h=320&q=80" />
# <div class="absolute inset-0 ring-1 ring-inset ring-black/10 rounded-lg"></div>
# </div>
# </div>
# </div>
# </div>
# ```
# ```html
# <div class="**backdrop-brightness-50** bg-white/30 ...">
# <!-- ... -->
# </div>
# <div class="**backdrop-brightness-125** bg-white/30 ...">
# <!-- ... -->
# </div>
# <div class="**backdrop-brightness-200** bg-white/30 ...">
# <!-- ... -->
# </div>
# ```
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# /* Output */
# .bg-brand-gradient {
# background-image: linear-gradient(#3490dc, #6574cd) !important;
# }
# ```
# #### Selector strategy
# Setting `important` to `true` can introduce some issues when incorporating third-party JS libraries that add inline styles to your elements. In those cases, Tailwind's `!important` utilities defeat the inline styles, which can break your intended design.
# To get around this, you can set `important` to an ID selector like `#app` instead:
# ```js {{ filename: 'tailwind.config.js' }}
# /** @type {import('tailwindcss').Config} */
# module.exports = {
# // ...
# important: '#app',
# }
# ```
# This configuration will prefix all of your utilities with the given selector, effectively increasing their specificity without actually making them `!important`.
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# is styled correctly by providing some additional options when creating the component:var stripe = Stripe('pk_test_TYooMQauvdEDq54NiTphI7jx');
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# </div>
# ```
# ```html
# <svg class="**stroke-1** ..."></svg>
# <svg class="**stroke-2** ..."></svg>
# ```
# This can be useful for styling icon sets like [Heroicons](https://heroicons.com).
# ---

# %% [markdown]
# ### First Try: LLMChainFilter
# Now let's wrap our base retriever with a ContextualCompressionRetriever. We'll add an LLMChainExtractor, which will iterate over the initially returned documents and extract from each only the content that is relevant to the query.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainFilter

llm = ChatOpenAI(temperature=0)



_filter = LLMChainFilter.from_llm(llm)
compression_retriever = ContextualCompressionRetriever(base_compressor=_filter, base_retriever=vector_store.as_retriever())




compression_retriever = ContextualCompressionRetriever(base_compressor=compressor, base_retriever=vector_store.as_retriever())

compressed_docs = compression_retriever.get_relevant_documents("What is the correct way to apply a gradient to a div?")
pretty_print_docs(compressed_docs)

# %%
from langchain.document_transformers import DocumentCompressorPipeline

pipeline = DocumentCompressorPipeline(transformers=[filter_ordered_by_retriever])
compression_retriever = ContextualCompressionRetriever(
    base_compressor=pipeline, base_retriever=lotr
)

# %%
from langchain.chat_models import ChatOpenAI
# from langchain.chat_models import OpenAI
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.retrievers import RePhraseQueryRetriever
from langchain.memory import ConversationBufferMemory


# Instantiate ConversationBufferMemory
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True, output_key='answer')

DEFAULT_TEMPLATE = """You are an assistant tasked with taking a natural language \
query from a user and converting it into a query for a vectorstore. \
In this process, you strip out information that is not relevant for \
the retrieval task. Here is the user query: {question}"""

llm = ChatOpenAI(temperature=0)
retriever_from_llm = RePhraseQueryRetriever.from_llm(
    retriever=vector_store.as_retriever(), llm=llm
)
# docs = retriever_from_llm.get_relevant_documents("How do I load documents from Hacker News?")

qa = ConversationalRetrievalChain.from_llm(llm=llm, retriever=vector_store.as_retriever(), memory=memory, return_source_documents=True)

# qa = RetrievalQA.from_llm(llm=llm, retriever=retriever_from_llm, memory=memory, return_source_documents=True, document_transformer=reorder)
# qa = RetrievalQA(document_transformer=reorder)

# %%
qa({ "question": "How do I make a full page gradient background?" })
# Out:
# 2023-11-06 20:28:39,010:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/rpc/match_tailwind_documents?limit=4 "HTTP/1.1 200 OK"
# {'question': 'How do I make a full page gradient background?',
#  'chat_history': [HumanMessage(content='How do I make a full page gradient background?'),
#   AIMessage(content='To create a full-page gradient background using Tailwind CSS, you can use the `bg-gradient-to` utility class along with the `from` and `to` values to define the gradient colors. Here\'s an example:\n\n```html\n<div class="bg-gradient-to-br from-blue-500 to-purple-500 h-screen">\n  <!-- Content goes here -->\n</div>\n```\n\nIn this example, the `bg-gradient-to-br` class creates a gradient that starts from the top left (`from`) and ends at the bottom right (`to`). The `from-blue-500` class sets the starting color of the gradient to a shade of blue, and the `to-purple-500` class sets the ending color to a shade of purple. The `h-screen` class ensures that the gradient covers the entire height of the screen.\n\nYou can customize the gradient colors by using different color classes from Tailwind\'s color palette. For example, you can use `from-red-500` and `to-yellow-500` to create a gradient from red to yellow.\n\nRemember to include the Tailwind CSS framework in your project and configure any necessary build steps to process the utility classes.')],
#  'answer': 'To create a full-page gradient background using Tailwind CSS, you can use the `bg-gradient-to` utility class along with the `from` and `to` values to define the gradient colors. Here\'s an example:\n\n```html\n<div class="bg-gradient-to-br from-blue-500 to-purple-500 h-screen">\n  <!-- Content goes here -->\n</div>\n```\n\nIn this example, the `bg-gradient-to-br` class creates a gradient that starts from the top left (`from`) and ends at the bottom right (`to`). The `from-blue-500` class sets the starting color of the gradient to a shade of blue, and the `to-purple-500` class sets the ending color to a shade of purple. The `h-screen` class ensures that the gradient covers the entire height of the screen.\n\nYou can customize the gradient colors by using different color classes from Tailwind\'s color palette. For example, you can use `from-red-500` and `to-yellow-500` to create a gradient from red to yellow.\n\nRemember to include the Tailwind CSS framework in your project and configure any necessary build steps to process the utility classes.',
#  'source_documents': [Document(page_content='<div class="relative">\n<div class="absolute inset-6 backdrop-brightness-200 h-20 w-20 bg-white/30"></div>\n<img class="w-32 h-32 object-cover rounded-lg shadow-xl" src="https://images.unsplash.com/photo-1554629947-334ff61d85dc?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=320&h=320&q=80" />\n<div class="absolute inset-0 ring-1 ring-inset ring-black/10 rounded-lg"></div>\n</div>\n</div>\n</div>\n</div>\n```  \n```html\n<div class="**backdrop-brightness-50** bg-white/30 ...">\n<!-- ... -->\n</div>\n<div class="**backdrop-brightness-125** bg-white/30 ...">\n<!-- ... -->\n</div>\n<div class="**backdrop-brightness-200** bg-white/30 ...">\n<!-- ... -->\n</div>\n```', metadata={'Header 2': 'Basic usage', 'Header 3': 'Controlling backdrop brightness'}),
#   Document(page_content='<div class="absolute inset-0 ring-1 ring-inset ring-black/10 rounded-lg"></div>\n</div>\n</div>\n<div class="flex flex-col items-center shrink-0">\n<p class="font-medium text-sm text-slate-500 font-mono text-center mb-3 dark:text-slate-400">backdrop-brightness-125</p>\n<div class="relative">\n<div class="absolute inset-6 backdrop-brightness-125 h-20 w-20 bg-white/30"></div>\n<img class="w-32 h-32 object-cover rounded-lg shadow-xl" src="https://images.unsplash.com/photo-1554629947-334ff61d85dc?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=320&h=320&q=80" />\n<div class="absolute inset-0 ring-1 ring-inset ring-black/10 rounded-lg"></div>\n</div>\n</div>\n<div class="flex flex-col items-center shrink-0">\n<p class="font-medium text-sm text-slate-500 font-mono text-center mb-3 dark:text-slate-400">backdrop-brightness-200</p>\n<div class="relative">\n<div class="absolute inset-6 backdrop-brightness-200 h-20 w-20 bg-white/30"></div>', metadata={'Header 2': 'Basic usage', 'Header 3': 'Controlling backdrop brightness'}),
#   Document(page_content="By default, Tailwind includes a handful of general purpose `backdrop-brightness` utilities. You can customize these values by editing `theme.backdropBrightness` or `theme.extend.backdropBrightness` in your `tailwind.config.js` file.  \n```diff-js {{ filename: 'tailwind.config.js' }}\nmodule.exports = {\ntheme: {\nextend: {\n+       backdropBrightness: {\n+         25: '.25',\n+         175: '1.75',\n+       }\n}\n}\n}\n```  \nLearn more about customizing the default theme in the [theme customization](/docs/theme#customizing-the-default-theme) documentation.", metadata={'Header 2': 'Using custom values', 'Header 3': 'Customizing your theme'}),
#   Document(page_content="/* Output */\n.bg-brand-gradient {\nbackground-image: linear-gradient(#3490dc, #6574cd) !important;\n}\n```  \n#### Selector strategy  \nSetting `important` to `true` can introduce some issues when incorporating third-party JS libraries that add inline styles to your elements. In those cases, Tailwind's `!important` utilities defeat the inline styles, which can break your intended design.  \nTo get around this, you can set `important` to an ID selector like `#app` instead:  \n```js {{ filename: 'tailwind.config.js' }}\n/** @type {import('tailwindcss').Config} */\nmodule.exports = {\n// ...\nimportant: '#app',\n}\n```  \nThis configuration will prefix all of your utilities with the given selector, effectively increasing their specificity without actually making them `!important`.", metadata={'Header 2': 'Configuration options', 'Header 3': 'Important'})]}

# %%
# # Fetch all rows to update
# response = supabase.table('tailwind_documents').select('id, metadata').execute()

# print(f"Fetched all rows. {response.data[0]}")
# # Check for errors
# # if response.error:
# #     raise Exception(response.error)

# rows = response.data

# # Update each row
# for row in rows:
#     if 'source' in row['metadata']:
#         if row['metadata']['source'].startswith('./docs/'):
#             # Modify the 'source' value in the 'metadata' JSON
#             # Split the string and remove the '.mdx' part
#             new_source_base = row['metadata']['source'].rsplit('.mdx', 1)[0]
#             # Replace the './docs/' part with the desired URL
#             new_source = new_source_base.replace('./docs/', 'https://tailwindcss.com/docs/')
#             row['metadata']['source'] = new_source
            
#             # Update the row in the database
#             update_response = supabase.table('tailwind_documents').update({
#                 'metadata': row['metadata']
#             }).eq('id', row['id']).execute()

# print("All rows have been updated.")
# Out:
# 2023-11-06 15:27:46,418:INFO - HTTP Request: GET https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/tailwind_documents?select=id%2C%20metadata "HTTP/1.1 200 OK"
# Fetched all rows. {'id': 'd1aa376e-acd4-4eb3-8fda-e36db431dc00', 'metadata': {'source': 'https://tailwindcss.com/docs/columns', 'category': 'NarrativeText', 'filename': 'columns.mdx', 'filetype': 'text/markdown', 'languages': ['eng'], 'page_number': 1, 'last_modified': '2023-11-06T13:59:23', 'file_directory': './docs'}}
# 2023-11-06 15:27:47,394:INFO - HTTP Request: PATCH https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/tailwind_documents?id=eq