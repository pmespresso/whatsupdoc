# %%
links = [
"https://github.com/vercel/next.js/discussions/48110",
"https://github.com/vercel/next.js/discussions/46300",
"https://github.com/vercel/next.js/discussions/46722",
"https://github.com/vercel/next.js/discussions/49607",
"https://github.com/vercel/next.js/discussions/56446",
"https://github.com/vercel/next.js/discussions/50479",
"https://github.com/vercel/next.js/discussions/54075",
"https://github.com/vercel/next.js/discussions/51135",
"https://github.com/vercel/next.js/discussions/49302",
"https://github.com/vercel/next.js/discussions/50034",
"https://github.com/vercel/next.js/discussions/56822",
"https://github.com/vercel/next.js/discussions/58862",
"https://github.com/vercel/next.js/discussions/48256",
"https://github.com/vercel/next.js/discussions/44635",
"https://github.com/vercel/next.js/discussions/49892",
"https://github.com/vercel/next.js/discussions/55393",
"https://github.com/vercel/next.js/discussions/53225",
"https://github.com/vercel/next.js/discussions/56594",
"https://github.com/vercel/next.js/discussions/56118",
"https://github.com/vercel/next.js/discussions/50399",
"https://github.com/vercel/next.js/discussions/48951",
"https://github.com/vercel/next.js/discussions/47781",
"https://github.com/vercel/next.js/discussions/47020",
"https://github.com/vercel/next.js/discussions/53868",
"https://github.com/vercel/next.js/discussions/51566",
"https://github.com/vercel/next.js/discussions/57066",
"https://github.com/vercel/next.js/discussions/51460",
"https://github.com/vercel/next.js/discussions/54162",
"https://github.com/vercel/next.js/discussions/48324",
"https://github.com/vercel/next.js/discussions/48420",
"https://github.com/vercel/next.js/discussions/50771",
"https://github.com/vercel/next.js/discussions/55734",
"https://github.com/vercel/next.js/discussions/47242",
"https://github.com/vercel/next.js/discussions/47952",
"https://github.com/vercel/next.js/discussions/49304",
"https://github.com/vercel/next.js/discussions/48445",
"https://github.com/vercel/next.js/discussions/52378",
"https://github.com/vercel/next.js/discussions/49645",
"https://github.com/vercel/next.js/discussions/49388",
"https://github.com/vercel/next.js/discussions/44472",
"https://github.com/vercel/next.js/discussions/50295",
"https://github.com/vercel/next.js/discussions/49325",
"https://github.com/vercel/next.js/discussions/49950",
"https://github.com/vercel/next.js/discussions/49371",
"https://github.com/vercel/next.js/discussions/47309",
"https://github.com/vercel/next.js/discussions/50383",
"https://github.com/vercel/next.js/discussions/54337",
"https://github.com/vercel/next.js/discussions/53810",
"https://github.com/vercel/next.js/discussions/49326",
"https://github.com/vercel/next.js/discussions/47736",
"https://github.com/vercel/next.js/discussions/49603",
"https://github.com/vercel/next.js/discussions/49540",
"https://github.com/vercel/next.js/discussions/49146",
"https://github.com/vercel/next.js/discussions/46795",
"https://github.com/vercel/next.js/discussions/56093",
"https://github.com/vercel/next.js/discussions/54528",
"https://github.com/vercel/next.js/discussions/53409",
"https://github.com/vercel/next.js/discussions/58110",
"https://github.com/vercel/next.js/discussions/48937",
"https://github.com/vercel/next.js/discussions/47070",
"https://github.com/vercel/next.js/discussions/46575",
"https://github.com/vercel/next.js/discussions/49465",
"https://github.com/vercel/next.js/discussions/52119",
"https://github.com/vercel/next.js/discussions/44506",
"https://github.com/vercel/next.js/discussions/47195",
"https://github.com/vercel/next.js/discussions/45777",
"https://github.com/vercel/next.js/discussions/44458",
"https://github.com/vercel/next.js/discussions/49666",
"https://github.com/vercel/next.js/discussions/51500",
"https://github.com/vercel/next.js/discussions/49891",
"https://github.com/vercel/next.js/discussions/47353",
"https://github.com/vercel/next.js/discussions/46654",
"https://github.com/vercel/next.js/discussions/52926",
"https://github.com/vercel/next.js/discussions/52013",
"https://github.com/vercel/next.js/discussions/46307"
]

# %%
# !pip install -Uq pip
# Out:
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install -Uq langchain openai langchain-community langchain-openai bs4

# %%
# from langchain.document_loaders import WebBaseLoader

# loader = WebBaseLoader(links)

# %%
from langchain_community.document_loaders.recursive_url_loader import RecursiveUrlLoader
from bs4 import BeautifulSoup as Soup

url = "https://github.com/vercel/next.js/discussions/"

loader = RecursiveUrlLoader(
    url=url, max_depth=2, extractor=lambda x: Soup(x, "html.parser").text
)
docs = loader.load()

# %%
len(docs)
# Out:
# 32

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

docs = loader.load_and_split()

print(len(docs))
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# 126
# vercel/next.js · Discussions · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
#           Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Product
#
#
#
#
#
#
#
#
#
#
#
#
#
# Actions
#         Automate any workflow
#
#
#
#
#
#
#
#
# Packages
#         Host and manage packages
#
#
#
#
#
#
#
#
# Security
#         Find and fix vulnerabilities
#
#
#
#
#
#
#
#
# Codespaces
#         Instant dev environments
#
#
#
#
#
#
#
#
# Copilot
#         Write better code with AI
#
#
#
#
#
#
#
#
# Code review
#         Manage code changes
#
#
#
#
#
#
#
#
# Issues
#         Plan and track work
#
#
#
#
#
#
#
#
# Discussions
#         Collaborate outside of code
#
#
#
#
#
# Explore
#
#
#
#       All features
#
#
#
#
#
#       Documentation
#
#
#
#
#
#
#
#       GitHub Skills
#
#
#
#
#
#
#
#       Blog
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
len(docs)
# Out:
# 126

# %%
from supabase.client import Client, create_client
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores.supabase import SupabaseVectorStore
import os
from dotenv import load_dotenv

load_dotenv()

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

embeddings = OpenAIEmbeddings()

# %%
vector_store = SupabaseVectorStore.from_documents(
    documents=docs[400:],
    embedding=embeddings,
    client=supabase,
    table_name="nextjs_documents",
    query_name="nextjs_match_documents",
    chunk_size=100
)
# Out:
# 2023-12-20 15:32:07,954:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/nextjs_documents "HTTP/1.1 201 Created"
# 2023-12-20 15:32:13,991:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/nextjs_documents "HTTP/1.1 201 Created"
# 2023-12-20 15:32:20,035:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/nextjs_documents "HTTP/1.1 201 Created"
# 2023-12-20 15:32:24,453:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/nextjs_documents "HTTP/1.1 201 Created"
# 2023-12-20 15:32:29,088:INFO - HTTP Request: POST https://qublpyarwoevdeqqicbz.supabase.co/rest/v1/nextjs_documents "HTTP/1.1 201 Created"
